# %% [markdown]
# ##問題1 Pandas列参照
# 以下のデータフレームから、役割のリストを作れ。
# ```
# import pandas as pd
# df = pd.DataFrame({
#     '名前' : ['田中', '山田', '高橋'],
#     '役割' : ['営業部長', '広報部', '技術責任者'],
#     '身長' : [178, 173, 169]
#     })
# ```
# 出力は、
# ```
# 0     営業部長
# 1      広報部
# 2    技術責任者
# Name: 役割, dtype: object
# ```

# %%
import pandas as pd
df = pd.DataFrame({
    '名前' : ['田中', '山田', '高橋'],
    '役割' : ['営業部長', '広報部', '技術責任者'],
    '身長' : [178, 173, 169]
    })
print(df)
print(?)
# Out:
#    名前     役割   身長
# 0  田中   営業部長  178
# 1  山田    広報部  173
# 2  高橋  技術責任者  169

# %% [markdown]
# ##問題2 Pandas行参照
# 上記のデータフレームから、第0番目の行を取り出せ。
#
# 出力は、以下とする。
# ```
# 名前      田中
# 役割    営業部長
# 身長     178
# Name: 0, dtype: object
# ```

# %%
print(?)

# %% [markdown]
# ##問題3 Pandas条件検索
# 問題6のデータフレームから、役割が技術責任者であるデータを取り出せ。
# 出力は以下とする。
#
# ```
#    名前     役割   身長
# 2  高橋  技術責任者  169
# ```

# %%
print(?)

# %% [markdown]
# ##問題4 Pandasソート
# 問題1のデータを、身長の昇順にソートせよ。

# %%
print(?)

# %% [markdown]
# ##問題5 Pandasデータ追加
# 問題1のデータに、"性別" [男、女、男]を追加し、印字せよ。出力は、以下の通り。
#
# ```
#    名前     役割   身長 性別
# 0  田中   営業部長  178  男
# 1  山田    広報部  173  女
# 2  高橋  技術責任者  169  男
# ```

# %%
?
print(df)
