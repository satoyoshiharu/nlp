# %% [markdown]
# ##問題1
# 以下のデバッグログから、'python3'　を含む行を印字せよ。

# %%
str = '''\
Oct 01 08:48:27 hmc-dialog-server python3[481]: 106.131.142.215 [30/Sep/2021:23:48:27 +0000] "GET /www/service-work>
Oct 01 08:48:31 hmc-dialog-server python3[11718]: kill: (11698): No such process
Oct 01 09:03:31 hmc-dialog-server python3[11863]: kill: (11702): No such process
Oct 01 09:17:01 hmc-dialog-server CRON[11995]: pam_unix(cron:session): session opened for user root by (uid=0)
Oct 01 09:17:01 hmc-dialog-server CRON[11996]: (root) CMD (   cd / && run-parts --report /etc/cron.hourly)
Oct 01 09:17:01 hmc-dialog-server CRON[11995]: pam_unix(cron:session): session closed for user root
Oct 01 09:34:57 hmc-dialog-server systemd[1]: Starting NSS cache refresh...
Oct 01 09:34:58 hmc-dialog-server systemd[1]: google-oslogin-cache.service: Succeeded.
Oct 01 09:34:58 hmc-dialog-server oslogin_cache_refresh[12169]: Refreshing passwd entry cache
Oct 01 09:34:58 hmc-dialog-server systemd[1]: Finished NSS cache refresh.
Oct 01 09:34:58 hmc-dialog-server oslogin_cache_refresh[12169]: Refreshing group entry cache
Oct 01 09:34:58 hmc-dialog-server google_oslogin_nss_cache[12169]: oslogin_cache_refresh[12169]: Refreshing passwd >
Oct 01 09:34:58 hmc-dialog-server google_oslogin_nss_cache[12169]: oslogin_cache_refresh[12169]: Refreshing group e>
Oct 01 09:47:01 hmc-dialog-server CRON[12290]: pam_unix(cron:session): session opened for user root by (uid=0)
Oct 01 09:47:01 hmc-dialog-server CRON[12291]: (root) CMD (   test -x /etc/cron.daily/popularity-contest && /etc/cr>
Oct 01 09:47:01 hmc-dialog-server CRON[12290]: pam_unix(cron:session): session closed for user root
'''
import re
regexp = r'_________' # <- 穴埋め
lines = str.split('\n')
for l in lines:
  if len(re.findall(regexp, l)) > 0: 
    print(l)

# %% [markdown]
# ##問題2
# 上記のログから、python3とCRONとsystemdの出力以外の行を取り出せ。

# %%
import re
regexp = r'________' # <- 穴埋め
lines = str.split('\n')
for l in lines:
  if len(re.findall(regexp, l)) == 0:
    print(l)

# %% [markdown]
# ##問題3
# 以下のurlから、プロトコル部分を抜き出せ。出力は、以下となる。
#
# ```
# ['https']
# ['wss']
# ['apps']
# ```

# %%
import re
regexp = r'________' # <- 穴埋め
print(re.findall(regexp, 'https://abc.com/def/'))
print(re.findall(regexp, 'wss://xyz.com:8080/'))
print(re.findall(regexp, 'apps://myapplication/'))

# %% [markdown]
# ##問題4
# urlから、ポート番号を除くドメイン名を抜き出せ。出力は、以下となる。
#
# ```
# ['abc.com']
# ['xyz.com']
# ['myapplication']
# ```

# %%
regexp = r'________' # <- 穴埋め
print(re.findall(regexp, 'https://abc.com/def/'))
print(re.findall(regexp, 'wss://xyz.com:8080/'))
print(re.findall(regexp, 'apps://myapplication/'))

# %% [markdown]
# #問題5
# urlから、ポート番号を含むドメイン名を抜き出せ。出力は、以下となる。
#
# ```
# ['abc.com']
# ['xyz.com:8080']
# ['myapplication']
# ```

# %%
regexp = r'________' # <- 穴埋め
print(re.findall(regexp, 'https://abc.com/def/'))
print(re.findall(regexp, 'wss://xyz.com:8080/'))
print(re.findall(regexp, 'apps://myapplication/'))
